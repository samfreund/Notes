# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Let's start by reading in a data set
#
# pandas has a built in csv reader, as well as readers for many other types of files

# %%
#Note - parts of this tutorial are inspired by https://realpython.com/pandas-python-explore-dataset/

ames = pd.read_csv("AmesHousing.csv")
type(ames)
# Out:
# pandas.core.frame.DataFrame

# %%
print(len(ames)) #rows in data set
print(ames.shape) #tuple with (rows, cols)
# Out:
# 2930
# (2930, 82)

# %%
# to get a view of the first five rows of the data set, use the .head() method
ames.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0   NaN       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 1   NaN       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 2   NaN       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 3   NaN       Reg          Lvl    AllPub     Corner        Gtl        NAmes
# 4   NaN       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 0        Norm        Norm      1Fam      1Story             6             5
# 1       Feedr        Norm      1Fam      1Story             5             6
# 2        Norm        Norm      1Fam      1Story             6             6
# 3        Norm        Norm      1Fam      1Story             7             5
# 4        Norm        Norm      1Fam      2Story             5             5
#
#    Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd  \
# 0        1960            1960        Hip   CompShg      BrkFace      Plywood
# 1        1961            1961      Gable   CompShg      VinylSd      VinylSd
# 2        1958            1958        Hip   CompShg      Wd Sdng      Wd Sdng
# 3        1968            1968        Hip   CompShg      BrkFace      BrkFace
# 4        1997            1998      Gable   CompShg      VinylSd      VinylSd
#
#   Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation Bsmt Qual  \
# 0        Stone         112.0         TA         TA     CBlock        TA
# 1          NaN           0.0         TA         TA     CBlock        TA
# 2      BrkFace         108.0         TA         TA     CBlock        TA
# 3          NaN           0.0         Gd         TA     CBlock        TA
# 4          NaN           0.0         TA         TA      PConc        Gd
#
#   Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  \
# 0        Gd            Gd            BLQ         639.0            Unf
# 1        TA            No            Rec         468.0            LwQ
# 2        TA            No            ALQ         923.0            Unf
# 3        TA            No            ALQ        1065.0            Unf
# 4        TA            No            GLQ         791.0            Unf
#
#    BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating Heating QC Central Air  \
# 0           0.0        441.0         1080.0    GasA         Fa           Y
# 1         144.0        270.0          882.0    GasA         TA           Y
# 2           0.0        406.0         1329.0    GasA         TA           Y
# 3           0.0       1045.0         2110.0    GasA         Ex           Y
# 4           0.0        137.0          928.0    GasA         Gd           Y
#
#   Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  Gr Liv Area  \
# 0      SBrkr        1656           0                0         1656
# 1      SBrkr         896           0                0          896
# 2      SBrkr        1329           0                0         1329
# 3      SBrkr        2110           0                0         2110
# 4      SBrkr         928         701                0         1629
#
#    Bsmt Full Bath  Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  \
# 0             1.0             0.0          1          0              3
# 1             0.0             0.0          1          0              2
# 2             0.0             0.0          1          1              3
# 3             1.0             0.0          2          1              3
# 4             0.0             0.0          2          1              3
#
#    Kitchen AbvGr Kitchen Qual  TotRms AbvGrd Functional  Fireplaces  \
# 0              1           TA              7        Typ           2
# 1              1           TA              5        Typ           0
# 2              1           Gd              6        Typ           0
# 3              1           Ex              8        Typ           2
# 4              1           TA              6        Typ           1
#
#   Fireplace Qu Garage Type  Garage Yr Blt Garage Finish  Garage Cars  \
# 0           Gd      Attchd         1960.0           Fin          2.0
# 1          NaN      Attchd         1961.0           Unf          1.0
# 2          NaN      Attchd         1958.0           Unf          1.0
# 3           TA      Attchd         1968.0           Fin          2.0
# 4           TA      Attchd         1997.0           Fin          2.0
#
#    Garage Area Garage Qual Garage Cond Paved Drive  Wood Deck SF  \
# 0        528.0          TA          TA           P           210
# 1        730.0          TA          TA           Y           140
# 2        312.0          TA          TA           Y           393
# 3        522.0          TA          TA           Y             0
# 4        482.0          TA          TA           Y           212
#
#    Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area Pool QC  \
# 0             62               0           0             0          0     NaN
# 1              0               0           0           120          0     NaN
# 2             36               0           0             0          0     NaN
# 3              0               0           0             0          0     NaN
# 4             34               0           0             0          0     NaN
#
#    Fence Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type Sale Condition  \
# 0    NaN          NaN         0        5     2010       WD          Normal
# 1  MnPrv          NaN         0        6     2010       WD          Normal
# 2    NaN         Gar2     12500        6     2010       WD          Normal
# 3    NaN          NaN         0        4     2010       WD          Normal
# 4  MnPrv          NaN         0        3     2010       WD          Normal
#
#    SalePrice
# 0     215000
# 1     105000
# 2     172000
# 3     244000
# 4     189900

# %%
# we are missing some columns - we can set an option to see all columns and be able to scroll
pd.set_option("display.max.columns", None)

# %%
# to display the last n rows, use .tail(n) - n defaults to 5 like for .head()
ames.tail(10)
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 2920   2921  923228310          160        RM          21.0      1894   Pave
# 2921   2922  923229110           90        RL          55.0     12640   Pave
# 2922   2923  923230040           90        RL          63.0      9297   Pave
# 2923   2924  923250060           20        RL          80.0     17400   Pave
# 2924   2925  923251180           20        RL         160.0     20000   Pave
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL           NaN      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
#      Alley Lot Shape Land Contour Utilities Lot Config Land Slope  \
# 2920   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 2921   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 2922   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 2923   NaN       Reg          Low    AllPub     Inside        Mod
# 2924   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 2925   NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 2926   NaN       IR1          Low    AllPub     Inside        Mod
# 2927   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 2928   NaN       Reg          Lvl    AllPub     Inside        Mod
# 2929   NaN       Reg          Lvl    AllPub     Inside        Mod
#
#      Neighborhood Condition 1 Condition 2 Bldg Type House Style  Overall Qual  \
# 2920      MeadowV        Norm        Norm    TwnhsE      2Story             4
# 2921      Mitchel        Norm        Norm    Duplex      1Story             6
# 2922      Mitchel        Norm        Norm    Duplex      1Story             5
# 2923      Mitchel        Norm        Norm      1Fam      1Story             5
# 2924      Mitchel        Norm        Norm      1Fam      1Story             5
# 2925      Mitchel        Norm        Norm      1Fam        SLvl             6
# 2926      Mitchel        Norm        Norm      1Fam      1Story             5
# 2927      Mitchel        Norm        Norm      1Fam      SFoyer             5
# 2928      Mitchel        Norm        Norm      1Fam      1Story             5
# 2929      Mitchel        Norm        Norm      1Fam      2Story             7
#
#       Overall Cond  Year Built  Year Remod/Add Roof Style Roof Matl  \
# 2920             5        1970            1970      Gable   CompShg
# 2921             5        1976            1976      Gable   CompShg
# 2922             5        1976            1976      Gable   CompShg
# 2923             5        1977            1977      Gable   CompShg
# 2924             7        1960            1996      Gable   CompShg
# 2925             6        1984            1984      Gable   CompShg
# 2926             5        1983            1983      Gable   CompShg
# 2927             5        1992            1992      Gable   CompShg
# 2928             5        1974            1975      Gable   CompShg
# 2929             5        1993            1994      Gable   CompShg
#
#      Exterior 1st Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual  \
# 2920      CemntBd      CmentBd          NaN           0.0         TA
# 2921      Plywood      Plywood          NaN           0.0         TA
# 2922      Plywood      Plywood          NaN           0.0         TA
# 2923      BrkFace      BrkFace          NaN           0.0         TA
# 2924      VinylSd      VinylSd          NaN           0.0         TA
# 2925      HdBoard      HdBoard          NaN           0.0         TA
# 2926      HdBoard      HdBoard          NaN           0.0         TA
# 2927      HdBoard      Wd Shng          NaN           0.0         TA
# 2928      HdBoard      HdBoard          NaN           0.0         TA
# 2929      HdBoard      HdBoard      BrkFace          94.0         TA
#
#      Exter Cond Foundation Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  \
# 2920         TA     CBlock        TA        TA            No            Rec
# 2921         TA     CBlock        TA        TA            Gd            Rec
# 2922         TA     CBlock        TA        TA            No            ALQ
# 2923         TA     CBlock        TA        TA            No            ALQ
# 2924         TA     CBlock        TA        TA            No            ALQ
# 2925         TA     CBlock        TA        TA            Av            GLQ
# 2926         TA     CBlock        Gd        TA            Av            BLQ
# 2927         TA      PConc        Gd        TA            Av            GLQ
# 2928         TA     CBlock        Gd        TA            Av            ALQ
# 2929         TA      PConc        Gd        TA            Av            LwQ
#
#       BsmtFin SF 1 BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF  \
# 2920         252.0            Unf           0.0        294.0          546.0
# 2921         936.0            LwQ         396.0        396.0         1728.0
# 2922        1606.0            Unf           0.0        122.0         1728.0
# 2923         936.0            Unf           0.0        190.0         1126.0
# 2924        1224.0            Unf           0.0          0.0         1224.0
# 2925         819.0            Unf           0.0        184.0         1003.0
# 2926         301.0            ALQ         324.0        239.0          864.0
# 2927         337.0            Unf           0.0        575.0          912.0
# 2928        1071.0            LwQ         123.0        195.0         1389.0
# 2929         758.0            Unf           0.0        238.0          996.0
#
#      Heating Heating QC Central Air Electrical  1st Flr SF  2nd Flr SF  \
# 2920    GasA         TA           Y      SBrkr         546         546
# 2921    GasA         TA           Y      SBrkr        1728           0
# 2922    GasA         TA           Y      SBrkr        1728           0
# 2923    GasA         Fa           Y      SBrkr        1126           0
# 2924    GasA         Ex           Y      SBrkr        1224           0
# 2925    GasA         TA           Y      SBrkr        1003           0
# 2926    GasA         TA           Y      SBrkr         902           0
# 2927    GasA         TA           Y      SBrkr         970           0
# 2928    GasA         Gd           Y      SBrkr        1389           0
# 2929    GasA         Ex           Y      SBrkr         996        1004
#
#       Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  Bsmt Half Bath  Full Bath  \
# 2920                0         1092             0.0             0.0          1
# 2921                0         1728             0.0             0.0          2
# 2922                0         1728             2.0             0.0          2
# 2923                0         1126             1.0             0.0          2
# 2924                0         1224             1.0             0.0          1
# 2925                0         1003             1.0             0.0          1
# 2926                0          902             1.0             0.0          1
# 2927                0          970             0.0             1.0          1
# 2928                0         1389             1.0             0.0          1
# 2929                0         2000             0.0             0.0          2
#
#       Half Bath  Bedroom AbvGr  Kitchen AbvGr Kitchen Qual  TotRms AbvGrd  \
# 2920          1              3              1           TA              6
# 2921          0              4              2           TA              8
# 2922          0              4              2           TA              8
# 2923          0              3              1           TA              5
# 2924          0              4              1           TA              7
# 2925          0              3              1           TA              6
# 2926          0              2              1           TA              5
# 2927          0              3              1           TA              6
# 2928          0              2              1           TA              6
# 2929          1              3              1           TA              9
#
#      Functional  Fireplaces Fireplace Qu Garage Type  Garage Yr Blt  \
# 2920        Typ           0          NaN     CarPort         1970.0
# 2921        Typ           0          NaN      Attchd         1976.0
# 2922        Typ           0          NaN      Detchd         1976.0
# 2923        Typ           1           Gd      Attchd         1977.0
# 2924        Typ           1           TA      Detchd         1960.0
# 2925        Typ           0          NaN      Detchd         1984.0
# 2926        Typ           0          NaN      Attchd         1983.0
# 2927        Typ           0          NaN         NaN            NaN
# 2928        Typ           1           TA      Attchd         1975.0
# 2929        Typ           1           TA      Attchd         1993.0
#
#      Garage Finish  Garage Cars  Garage Area Garage Qual Garage Cond  \
# 2920           Unf          1.0        286.0          TA          TA
# 2921           Unf          2.0        574.0          TA          TA
# 2922           Unf          2.0        560.0          TA          TA
# 2923           RFn          2.0        484.0          TA          TA
# 2924           Unf          2.0        576.0          TA          TA
# 2925           Unf          2.0        588.0          TA          TA
# 2926           Unf          2.0        484.0          TA          TA
# 2927           NaN          0.0          0.0         NaN         NaN
# 2928           RFn          2.0        418.0          TA          TA
# 2929           Fin          3.0        650.0          TA          TA
#
#      Paved Drive  Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  \
# 2920           Y             0             24               0           0
# 2921           Y            40              0               0           0
# 2922           Y             0              0               0           0
# 2923           P           295             41               0           0
# 2924           Y           474              0               0           0
# 2925           Y           120              0               0           0
# 2926           Y           164              0               0           0
# 2927           Y            80             32               0           0
# 2928           Y           240             38               0           0
# 2929           Y           190             48               0           0
#
#       Screen Porch  Pool Area Pool QC  Fence Misc Feature  Misc Val  Mo Sold  \
# 2920             0          0     NaN    NaN          NaN         0        4
# 2921             0          0     NaN    NaN          NaN         0        7
# 2922             0          0     NaN    NaN          NaN         0        7
# 2923             0          0     NaN    NaN          NaN         0        5
# 2924             0          0     NaN    NaN          NaN         0        9
# 2925             0          0     NaN  GdPrv          NaN         0        3
# 2926             0          0     NaN  MnPrv          NaN         0        6
# 2927             0          0     NaN  MnPrv         Shed       700        7
# 2928             0          0     NaN    NaN          NaN         0        4
# 2929             0          0     NaN    NaN          NaN         0       11
#
#       Yr Sold Sale Type Sale Condition  SalePrice
# 2920     2006       WD         Abnorml      71000
# 2921     2006       WD          Normal     150900
# 2922     2006       WD          Family     188000
# 2923     2006       WD          Normal     160000
# 2924     2006       WD         Abnorml     131000
# 2925     2006       WD          Normal     142500
# 2926     2006       WD          Normal     131000
# 2927     2006       WD          Normal     132000
# 2928     2006       WD          Normal     170000
# 2929     2006       WD          Normal     188000

# %%
# like numpy arrays, each column in pandas has a data type
# unlike numpy arrays, each column can have a different data type

#view data types for each column with the .info() method
ames.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 82 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order            2930 non-null   int64
#  1   PID              2930 non-null   int64
#  2   MS SubClass      2930 non-null   int64
#  3   MS Zoning        2930 non-null   object
#  4   Lot Frontage     2440 non-null   float64
#  5   Lot Area         2930 non-null   int64
#  6   Street           2930 non-null   object
#  7   Alley            198 non-null    object
#  8   Lot Shape        2930 non-null   object
#  9   Land Contour     2930 non-null   object
#  10  Utilities        2930 non-null   object
#  11  Lot Config       2930 non-null   object
#  12  Land Slope       2930 non-null   object
#  13  Neighborhood     2930 non-null   object
#  14  Condition 1      2930 non-null   object
#  15  Condition 2      2930 non-null   object
#  16  Bldg Type        2930 non-null   object
#  17  House Style      2930 non-null   object
#  18  Overall Qual     2930 non-null   int64
#  19  Overall Cond     2930 non-null   int64
#  20  Year Built       2930 non-null   int64
#  21  Year Remod/Add   2930 non-null   int64
#  22  Roof Style       2930 non-null   object
#  23  Roof Matl        2930 non-null   object
#  24  Exterior 1st     2930 non-null   object
#  25  Exterior 2nd     2930 non-null   object
#  26  Mas Vnr Type     1155 non-null   object
#  27  Mas Vnr Area     2907 non-null   float64
#  28  Exter Qual       2930 non-null   object
#  29  Exter Cond       2930 non-null   object
#  30  Foundation       2930 non-null   object
#  31  Bsmt Qual        2850 non-null   object
#  32  Bsmt Cond        2850 non-null   object
#  33  Bsmt Exposure    2847 non-null   object
#  34  BsmtFin Type 1   2850 non-null   object
#  35  BsmtFin SF 1     2929 non-null   float64
#  36  BsmtFin Type 2   2849 non-null   object
#  37  BsmtFin SF 2     2929 non-null   float64
#  38  Bsmt Unf SF      2929 non-null   float64
#  39  Total Bsmt SF    2929 non-null   float64
#  40  Heating          2930 non-null   object
#  41  Heating QC       2930 non-null   object
#  42  Central Air      2930 non-null   object
#  43  Electrical       2929 non-null   object
#  44  1st Flr SF       2930 non-null   int64
#  45  2nd Flr SF       2930 non-null   int64
#  46  Low Qual Fin SF  2930 non-null   int64
#  47  Gr Liv Area      2930 non-null   int64
#  48  Bsmt Full Bath   2928 non-null   float64
#  49  Bsmt Half Bath   2928 non-null   float64
#  50  Full Bath        2930 non-null   int64
#  51  Half Bath        2930 non-null   int64
#  52  Bedroom AbvGr    2930 non-null   int64
#  53  Kitchen AbvGr    2930 non-null   int64
#  54  Kitchen Qual     2930 non-null   object
#  55  TotRms AbvGrd    2930 non-null   int64
#  56  Functional       2930 non-null   object
#  57  Fireplaces       2930 non-null   int64
#  58  Fireplace Qu     1508 non-null   object
#  59  Garage Type      2773 non-null   object
#  60  Garage Yr Blt    2771 non-null   float64
#  61  Garage Finish    2771 non-null   object
#  62  Garage Cars      2929 non-null   float64
#  63  Garage Area      2929 non-null   float64
#  64  Garage Qual      2771 non-null   object
#  65  Garage Cond      2771 non-null   object
#  66  Paved Drive      2930 non-null   object
#  67  Wood Deck SF     2930 non-null   int64
#  68  Open Porch SF    2930 non-null   int64
#  69  Enclosed Porch   2930 non-null   int64
#  70  3Ssn Porch       2930 non-null   int64
#  71  Screen Porch     2930 non-null   int64
#  72  Pool Area        2930 non-null   int64
#  73  Pool QC          13 non-null     object
#  74  Fence            572 non-null    object
#  75  Misc Feature     106 non-null    object
#  76  Misc Val         2930 non-null   int64
#  77  Mo Sold          2930 non-null   int64
#  78  Yr Sold          2930 non-null   int64
#  79  Sale Type        2930 non-null   object
#  80  Sale Condition   2930 non-null   object
#  81  SalePrice        2930 non-null   int64
# dtypes: float64(11), int64(28), object(43)
# memory usage: 1.8+ MB

# %%
# a brief description of the numeric columns can be obtained using the .describe() method
ames.describe()
# Out:
#             Order           PID  MS SubClass  Lot Frontage       Lot Area  \
# count  2930.00000  2.930000e+03  2930.000000   2440.000000    2930.000000
# mean   1465.50000  7.144645e+08    57.387372     69.224590   10147.921843
# std     845.96247  1.887308e+08    42.638025     23.365335    7880.017759
# min       1.00000  5.263011e+08    20.000000     21.000000    1300.000000
# 25%     733.25000  5.284770e+08    20.000000     58.000000    7440.250000
# 50%    1465.50000  5.354536e+08    50.000000     68.000000    9436.500000
# 75%    2197.75000  9.071811e+08    70.000000     80.000000   11555.250000
# max    2930.00000  1.007100e+09   190.000000    313.000000  215245.000000
#
#        Overall Qual  Overall Cond   Year Built  Year Remod/Add  Mas Vnr Area  \
# count   2930.000000   2930.000000  2930.000000     2930.000000   2907.000000
# mean       6.094881      5.563140  1971.356314     1984.266553    101.896801
# std        1.411026      1.111537    30.245361       20.860286    179.112611
# min        1.000000      1.000000  1872.000000     1950.000000      0.000000
# 25%        5.000000      5.000000  1954.000000     1965.000000      0.000000
# 50%        6.000000      5.000000  1973.000000     1993.000000      0.000000
# 75%        7.000000      6.000000  2001.000000     2004.000000    164.000000
# max       10.000000      9.000000  2010.000000     2010.000000   1600.000000
#
#        BsmtFin SF 1  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF   1st Flr SF  \
# count   2929.000000   2929.000000  2929.000000    2929.000000  2930.000000
# mean     442.629566     49.722431   559.262547    1051.614544  1159.557679
# std      455.590839    169.168476   439.494153     440.615067   391.890885
# min        0.000000      0.000000     0.000000       0.000000   334.000000
# 25%        0.000000      0.000000   219.000000     793.000000   876.250000
# 50%      370.000000      0.000000   466.000000     990.000000  1084.000000
# 75%      734.000000      0.000000   802.000000    1302.000000  1384.000000
# max     5644.000000   1526.000000  2336.000000    6110.000000  5095.000000
#
#         2nd Flr SF  Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  \
# count  2930.000000      2930.000000  2930.000000     2928.000000
# mean    335.455973         4.676792  1499.690444        0.431352
# std     428.395715        46.310510   505.508887        0.524820
# min       0.000000         0.000000   334.000000        0.000000
# 25%       0.000000         0.000000  1126.000000        0.000000
# 50%       0.000000         0.000000  1442.000000        0.000000
# 75%     703.750000         0.000000  1742.750000        1.000000
# max    2065.000000      1064.000000  5642.000000        3.000000
#
#        Bsmt Half Bath    Full Bath    Half Bath  Bedroom AbvGr  Kitchen AbvGr  \
# count     2928.000000  2930.000000  2930.000000    2930.000000    2930.000000
# mean         0.061134     1.566553     0.379522       2.854266       1.044369
# std          0.245254     0.552941     0.502629       0.827731       0.214076
# min          0.000000     0.000000     0.000000       0.000000       0.000000
# 25%          0.000000     1.000000     0.000000       2.000000       1.000000
# 50%          0.000000     2.000000     0.000000       3.000000       1.000000
# 75%          0.000000     2.000000     1.000000       3.000000       1.000000
# max          2.000000     4.000000     2.000000       8.000000       3.000000
#
#        TotRms AbvGrd   Fireplaces  Garage Yr Blt  Garage Cars  Garage Area  \
# count    2930.000000  2930.000000    2771.000000  2929.000000  2929.000000
# mean        6.443003     0.599317    1978.132443     1.766815   472.819734
# std         1.572964     0.647921      25.528411     0.760566   215.046549
# min         2.000000     0.000000    1895.000000     0.000000     0.000000
# 25%         5.000000     0.000000    1960.000000     1.000000   320.000000
# 50%         6.000000     1.000000    1979.000000     2.000000   480.000000
# 75%         7.000000     1.000000    2002.000000     2.000000   576.000000
# max        15.000000     4.000000    2207.000000     5.000000  1488.000000
#
#        Wood Deck SF  Open Porch SF  Enclosed Porch   3Ssn Porch  Screen Porch  \
# count   2930.000000    2930.000000     2930.000000  2930.000000   2930.000000
# mean      93.751877      47.533447       23.011604     2.592491     16.002048
# std      126.361562      67.483400       64.139059    25.141331     56.087370
# min        0.000000       0.000000        0.000000     0.000000      0.000000
# 25%        0.000000       0.000000        0.000000     0.000000      0.000000
# 50%        0.000000      27.000000        0.000000     0.000000      0.000000
# 75%      168.000000      70.000000        0.000000     0.000000      0.000000
# max     1424.000000     742.000000     1012.000000   508.000000    576.000000
#
#          Pool Area      Misc Val      Mo Sold      Yr Sold      SalePrice
# count  2930.000000   2930.000000  2930.000000  2930.000000    2930.000000
# mean      2.243345     50.635154     6.216041  2007.790444  180796.060068
# std      35.597181    566.344288     2.714492     1.316613   79886.692357
# min       0.000000      0.000000     1.000000  2006.000000   12789.000000
# 25%       0.000000      0.000000     4.000000  2007.000000  129500.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  160000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  213500.000000
# max     800.000000  17000.000000    12.000000  2010.000000  755000.000000

# %%
# we probably do not need all 82 columns - lets select the columns we really care about

# to select a specific subset of columns, put a list of the col names in the selection brackets
ames = ames[["Lot Area", "Year Built", "Street", "Bldg Type", "SalePrice", "House Style", "Fireplaces", "Overall Qual", "Overall Cond"]]
ames.head()
# Out:
#    Lot Area  Year Built Street Bldg Type  SalePrice House Style  Fireplaces  \
# 0     31770        1960   Pave      1Fam     215000      1Story           2
# 1     11622        1961   Pave      1Fam     105000      1Story           0
# 2     14267        1958   Pave      1Fam     172000      1Story           0
# 3     11160        1968   Pave      1Fam     244000      1Story           2
# 4     13830        1997   Pave      1Fam     189900      2Story           1
#
#    Overall Qual  Overall Cond
# 0             6             5
# 1             5             6
# 2             6             6
# 3             7             5
# 4             5             5

# %%
# to determine how often specific values occur in a column,
# use the .value_counts() method on that columnn

print(ames["Overall Qual"].value_counts())
print()
print(ames["Street"].value_counts())
# Out:
# Overall Qual
# 5     825
# 6     732
# 7     602
# 8     350
# 4     226
# 9     107
# 3      40
# 10     31
# 2      13
# 1       4
# Name: count, dtype: int64
#
# Street
# Pave    2918
# Grvl      12
# Name: count, dtype: int64

# %%
# imagine you want to know more about houses that have a quality score of 10

ames[ames["Overall Qual"] == 10].describe() # returns a smaller data frame with just quality == 10
# Out:
#            Lot Area   Year Built      SalePrice  Fireplaces  Overall Qual  \
# count     31.000000    31.000000      31.000000   31.000000          31.0
# mean   18070.838710  1997.483871  450217.322581    1.354839          10.0
# std    11660.283113    28.301791  141975.967956    0.550659           0.0
# min     3951.000000  1892.000000  160000.000000    1.000000          10.0
# 25%    12586.000000  2003.000000  385625.000000    1.000000          10.0
# 50%    13870.000000  2006.000000  451950.000000    1.000000          10.0
# 75%    16610.500000  2007.000000  540112.000000    2.000000          10.0
# max    63887.000000  2009.000000  755000.000000    3.000000          10.0
#
#        Overall Cond
# count     31.000000
# mean       5.290323
# std        1.006431
# min        5.000000
# 25%        5.000000
# 50%        5.000000
# 75%        5.000000
# max        9.000000

# %%
# is the overall quality reflective of the price of the house?

# groupby allows you to compress your data based on some criteria
# if you pass in a column name, it will group by the possible options 
# for that column

#Note, groupby() returns a groupby object that you have to call a method on
# it works by "split-apply-combine" in that you split your data on some 
# criteria, apply some method to it, then combine the results 
dataByQual = ames.groupby("Overall Qual").mean(numeric_only = True)
dataByQual
# Out:
#                   Lot Area   Year Built      SalePrice  Fireplaces  \
# Overall Qual
# 1             15213.500000  1942.750000   48725.000000    0.000000
# 2              9326.230769  1933.307692   52325.307692    0.153846
# 3              9439.025000  1931.425000   83185.975000    0.075000
# 4              8464.411504  1946.119469  106485.097345    0.185841
# 5              9995.739394  1955.115152  134752.516364    0.364848
# 6              9787.922131  1967.963115  162130.318306    0.659836
# 7             10308.980066  1988.476744  205025.760797    0.724252
# 8             10617.842857  1997.340000  270913.594286    0.925714
# 9             12776.700935  2004.831776  368336.766355    1.149533
# 10            18070.838710  1997.483871  450217.322581    1.354839
#
#               Overall Cond
# Overall Qual
# 1                 3.000000
# 2                 3.538462
# 3                 4.475000
# 4                 5.446903
# 5                 5.824242
# 6                 5.795082
# 7                 5.430233
# 8                 5.205714
# 9                 4.953271
# 10                5.290323

# %%
# Problem: you want to see the stats for the top 10 most expensive houses in the data set

#first sort the data by price
ames = ames.sort_values(by = ["SalePrice", 'Year Built'], ascending=False) #sort by col "SalePrice" in descending order
ames.head(10) #passing a number into head will reveal that many rows
# Out:
#       Lot Area  Year Built Street Bldg Type  SalePrice House Style  \
# 1767     21535        1994   Pave      1Fam     755000      2Story
# 1760     15623        1996   Pave      1Fam     745000      2Story
# 2445     35760        1995   Pave      1Fam     625000      2Story
# 1063     12720        2003   Pave      1Fam     615000      1Story
# 44       12919        2009   Pave      1Fam     611657      1Story
# 432      13693        2007   Pave      1Fam     610000      1Story
# 1637     51974        2006   Pave      1Fam     591587      1Story
# 2450     17242        1993   Pave      1Fam     584500      2Story
# 433      13891        2008   Pave      1Fam     582933      2Story
# 2332     16056        2005   Pave      1Fam     556581      2Story
#
#       Fireplaces  Overall Qual  Overall Cond
# 1767           2            10             6
# 1760           2            10             5
# 2445           1            10             5
# 1063           2            10             5
# 44             2             9             5
# 432            2            10             5
# 1637           2             9             5
# 2450           1             9             5
# 433            1             9             5
# 2332           1             9             5

# %% [markdown]
# # More general pandas info

# %%
# grab a single column
singleColumn = ames["SalePrice"]
type(singleColumn)
# Out:
# pandas.core.series.Series

# %%
# A single column of a data frame is a "series" 
# Consequently, data frames are groups of series that share an index

#each series has an index and values (like a dictionary)

print(singleColumn.index)
print()
print(singleColumn.values)
# Out:
# Index([1767, 1760, 2445, 1063,   44,  432, 1637, 2450,  433, 2332,
#        ...
#         708,  727, 1555, 1901,  709, 2880, 2843,  726, 1553,  181],
#       dtype='int64', length=2930)
#
# [755000 745000 625000 ...  34900  13100  12789]

# %%
# also noteworthy is that pandas is built on numpy
type(singleColumn.values)
# Out:
# numpy.ndarray

# %%
# you can create series from both lists and dictionaries

# from a list
enrollmentSeries = pd.Series([8624,44718,31672], index = ["Notre Dame", "Michigan", "Alabama"])
print(enrollmentSeries)
print()

#from a dictionary
championships = {"Notre Dame" : 13,
                "Michigan": 11,
                "Alabama" : 15}

championshipSeries = pd.Series(championships) #keys become index, values are values
print(championshipSeries)
# Out:
# Notre Dame     8624
# Michigan      44718
# Alabama       31672
# dtype: int64
#
# Notre Dame    13
# Michigan      11
# Alabama       15
# dtype: int64

# %%
# because these two series have the same index, 
#they can be combined into a data frame 

schoolData = pd.DataFrame({"Enrollment":enrollmentSeries,
                          "Championships":championshipSeries})
schoolData
# Out:
#             Enrollment  Championships
# Notre Dame        8624             13
# Michigan         44718             11
# Alabama          31672             15

# %%
# data frames are also built using numpy arrays
schoolData.values
# Out:
# array([[ 8624,    13],
#        [44718,    11],
#        [31672,    15]])

# %%
# Easiest way to think about data frames is a dictionary of series objects
# Can access rows by their label

schoolData["Enrollment"] #Returns a series object
# Out:
# Notre Dame     8624
# Michigan      44718
# Alabama       31672
# Name: Enrollment, dtype: int64

# %%
# To get a specific enrollment number, call the index of that column
schoolData["Enrollment"]["Notre Dame"]
# Out:
# np.int64(8624)

# %%
# to access specific rows, use the .loc method
schoolData.loc["Michigan"]
# Out:
# Enrollment       44718
# Championships       11
# Name: Michigan, dtype: int64

# %%
# You can also access rows by their row number (zero indexed) using .iloc
schoolData.iloc[1]
# Out:
# Enrollment       44718
# Championships       11
# Name: Michigan, dtype: int64

# %%
# You can query your data frame using boolean logic
since2000 = ames[ames["Year Built"] >= 2000] #put a condition on a series in the data frame
since2000.shape
# Out:
# (783, 9)

# %%
# you can combine conditions together as well

newDataFrame = ames[
    (ames["Year Built"] > 2000) &
    (ames["SalePrice"] < 200000) & 
    (ames["Bldg Type"] == "1Fam")
                   ]
newDataFrame
# Out:
#       Lot Area  Year Built Street Bldg Type  SalePrice House Style  \
# 51       18494        2005   Pave      1Fam     199500      1Story
# 2459     10936        2006   Pave      1Fam     199000      1Story
# 251      10402        2009   Pave      1Fam     198900      1Story
# 2460      8640        2006   Pave      1Fam     198600      1Story
# 887       7301        2003   Pave      1Fam     198500      SFoyer
# ...        ...         ...    ...       ...        ...         ...
# 281       8546        2003   Pave      1Fam     140000      1Story
# 2470      7733        2005   Pave      1Fam     139500      1Story
# 2472     13072        2005   Pave      1Fam     132000      1Story
# 2823      8050        2002   Pave      1Fam     117250      1Story
# 2907     17217        2006   Pave      1Fam      84500      1Story
#
#       Fireplaces  Overall Qual  Overall Cond
# 51             0             6             5
# 2459           0             8             5
# 251            0             7             5
# 2460           0             8             5
# 887            1             7             5
# ...          ...           ...           ...
# 281            0             4             5
# 2470           0             6             5
# 2472           0             6             5
# 2823           0             6             5
# 2907           0             5             5
#
# [169 rows x 9 columns]

# %%
# you can also create new columns based on the data in the old columns

ames["TotalScore"] = ames["Overall Cond"] + ames["Overall Qual"]

ames.head()
# Out:
#       Lot Area  Year Built Street Bldg Type  SalePrice House Style  \
# 1767     21535        1994   Pave      1Fam     755000      2Story
# 1760     15623        1996   Pave      1Fam     745000      2Story
# 2445     35760        1995   Pave      1Fam     625000      2Story
# 1063     12720        2003   Pave      1Fam     615000      1Story
# 44       12919        2009   Pave      1Fam     611657      1Story
#
#       Fireplaces  Overall Qual  Overall Cond  TotalScore
# 1767           2            10             6          16
# 1760           2            10             5          15
# 2445           1            10             5          15
# 1063           2            10             5          15
# 44             2             9             5          14

# %%
# pandas also interfaces with matplotlib 
# x axis defaults to index values, y axis to what you specify

# to plot whether total score is correlated with sale price, create 
# data frame with total score as index
totalScoreDF = ames.groupby("TotalScore").mean(numeric_only = True)
totalScoreDF
# Out:
#                 Lot Area   Year Built      SalePrice  Fireplaces  \
# TotalScore
# 2           10020.000000  1922.000000   61000.000000    0.000000
# 3           11340.000000  1920.000000   55000.000000    0.000000
# 4           13422.200000  1943.200000   52497.800000    0.200000
# 5            7685.285714  1925.571429   62168.571429    0.142857
# 6           12640.600000  1923.400000   64480.266667    0.000000
# 7            9691.740741  1944.740741   92570.000000    0.222222
# 8            9699.372881  1942.508475   94761.525424    0.254237
# 9            9702.383459  1950.902256  117580.751880    0.338346
# 10          10135.302452  1960.373297  132074.528610    0.337875
# 11           9593.915335  1969.405751  151604.892971    0.535144
# 12           9713.857843  1979.568627  179495.007353    0.587010
# 13          10418.148014  1980.933213  227403.588448    0.803249
# 14          11529.657895  1974.271930  269656.609649    0.881579
# 15          13867.063492  1970.904762  306589.476190    1.142857
# 16          12145.705882  1945.470588  266894.117647    1.235294
# 17          12028.222222  1930.111111  251494.444444    0.888889
# 19          18225.000000  1892.500000  400000.000000    1.500000
#
#             Overall Qual  Overall Cond
# TotalScore
# 2               1.000000      1.000000
# 3               2.000000      1.000000
# 4               1.800000      2.200000
# 5               2.857143      2.142857
# 6               3.000000      3.000000
# 7               3.481481      3.518519
# 8               4.118644      3.881356
# 9               4.398496      4.601504
# 10              4.877384      5.122616
# 11              5.514377      5.485623
# 12              6.332108      5.667892
# 13              7.157040      5.842960
# 14              7.635965      6.364035
# 15              8.365079      6.634921
# 16              7.352941      8.647059
# 17              8.000000      9.000000
# 19             10.000000      9.000000

# %%
totalScoreDF["SalePrice"].plot()
#can add to plot just like for matplotlib
plt.ylabel("Sale Price")
# Out:
# Text(0, 0.5, 'Sale Price')

# %%
#personal opinion - it is easier to work with matplotlib alone than 
# plotting from data frames directly - matplotlib interfaces well with pandas

plt.plot(totalScoreDF.index,totalScoreDF["SalePrice"])
plt.xlabel("Total Score")
plt.ylabel("Sale Price")
plt.xticks(np.arange(2,20,2))
# Out:
# ([<matplotlib.axis.XTick at 0x7b9444771340>,
#   <matplotlib.axis.XTick at 0x7b94447182f0>,
#   <matplotlib.axis.XTick at 0x7b9444c5e630>,
#   <matplotlib.axis.XTick at 0x7b9444aa1280>,
#   <matplotlib.axis.XTick at 0x7b9444aa16a0>,
#   <matplotlib.axis.XTick at 0x7b9444aa2060>,
#   <matplotlib.axis.XTick at 0x7b9444aa2a20>,
#   <matplotlib.axis.XTick at 0x7b9444aa3350>,
#   <matplotlib.axis.XTick at 0x7b9444aa3ce0>],
#  [Text(2, 0, '2'),
#   Text(4, 0, '4'),
#   Text(6, 0, '6'),
#   Text(8, 0, '8'),
#   Text(10, 0, '10'),
#   Text(12, 0, '12'),
#   Text(14, 0, '14'),
#   Text(16, 0, '16'),
#   Text(18, 0, '18')])

# %% [markdown]
# # Examples
#
# Download the 2021_batting_data.csv file from Canvas (Data from baseball-reference.com). Read this data set into a pandas Da and answer the following questions:
#
# 1) Of players with less than 40 at bats, who has the highest number of home runs (HR)?
#
# 2) What is the age of the player on the Minnesota Twins (team id MIN) has the highest number of walks (BB)?
#
# 3) Create a new column called SO/AB that calculates how often a player strikes out (SO) divided by the number of at-bats for that player (AB). Of non-pitchers (pitchers have a Pos Summary == "/1"), which player has the highest highest SO/AB in the league?
#
# 4) Create a plot (either natively in matplotlib or with pandas plotting tool) that plots total number of at-bats on the x-axis and the average SO/AB for a player with that number of at-bats on the y-axis. HINT: you will probably want to use groupby() on the AB column to do this. Can you draw any conclusions from this plot?

# %%
data = pd.read_csv("2021_batting_data.csv")
data.head()
# Out:
#    Rk                        Name  Age   Tm  Lg   G  PA  AB   R   H  2B  3B  \
# 0   1        José Abreu\abreujo02   34  CHW  AL  16  71  60   6  12   2   0
# 1   2  Ronald Acuna Jr.\acunaro01   23  ATL  NL  16  72  62  21  26   6   1
# 2   3         Jason Adam\adamja01   29  CHC  NL   6   0   0   0   0   0   0
# 3   4      Willy Adames\adamewi01   25  TBR  AL  16  52  50   4   9   3   0
# 4   5      Austin Adams\adamsau02   30  SDP  NL   4   0   0   0   0   0   0
#
#    HR  RBI  SB  CS  BB  SO     BA    OBP    SLG    OPS   OPS+  TB  GDP  HBP  \
# 0   2   11   1   0  10  22  0.200  0.310  0.333  0.643   86.0  20    3    0
# 1   7   16   3   0   9  10  0.419  0.486  0.887  1.373  253.0  55    0    0
# 2   0    0   0   0   0   0    NaN    NaN    NaN    NaN    NaN   0    0    0
# 3   2    4   0   1   2  18  0.180  0.212  0.360  0.572   67.0  18    0    0
# 4   0    0   0   0   0   0    NaN    NaN    NaN    NaN    NaN   0    0    0
#
#    SH  SF  IBB Pos Summary
# 0   0   1    0          *3
# 1   0   1    0          *9
# 2   0   0    0          /1
# 3   0   0    0        *6/H
# 4   0   0    0          /1

# %%
lessForty = data[data["AB"] < 40]
lessForty = lessForty.sort_values(by = ["HR"], ascending=False)
lessForty.head(1)

# Byron Buxton is the player with the highest home runs out of the group of players with < 40 ABs
# Out:
#     Rk                    Name  Age   Tm  Lg  G  PA  AB  R   H  2B  3B  HR  \
# 97  98  Byron Buxton\buxtoby01   27  MIN  AL  9  36  32  8  15   5   0   5
#
#     RBI  SB  CS  BB  SO     BA    OBP    SLG    OPS   OPS+  TB  GDP  HBP  SH  \
# 97    9   1   0   2   6  0.469  0.528  1.094  1.622  362.0  35    0    2   0
#
#     SF  IBB Pos Summary   SO/AB
# 97   0    0          /8  0.1875

# %%
twins = data[data["Tm"] == "MIN"]
twins = twins.sort_values(by = ["BB"], ascending=False)
twins.head(1)

# The age of the player with the highest number of walks on the Minnesota Twins is 28 years old
# Out:
#       Rk                  Name  Age   Tm  Lg   G  PA  AB  R  H  2B  3B  HR  \
# 561  562  Miguel Sano\sanomi01   28  MIN  AL  14  56  43  6  5   0   0   2
#
#      RBI  SB  CS  BB  SO     BA    OBP    SLG    OPS  OPS+  TB  GDP  HBP  SH  \
# 561    4   0   0  13  19  0.116  0.321  0.256  0.577  73.0  11    1    0   0
#
#      SF  IBB Pos Summary    SO/AB
# 561   0    0      *3/5DH  0.44186

# %%
data["SO/AB"] = data["SO"] / data["AB"]
# Sort non-pitchers (Pos Summary != "/1") by SO/AB descending
non_pitchers = data[data["Pos Summary"] != "/1"]
non_pitchers = non_pitchers.sort_values(by="SO/AB", ascending=False)
non_pitchers.head(3)

# We can see that there are three players with an SO/AB of 1.0, namely Carter Kieboom, Sheldon Neuse and Ryan McBroom
# Out:
#       Rk                      Name  Age   Tm  Lg  G  PA  AB  R  H  2B  3B  HR  \
# 343  344  Carter Kieboom\kieboca01   23  WSN  NL  2   2   1  0  0   0   0   0
# 406  407    Ryan McBroom\mcbrory01   29  KCR  AL  3   5   4  1  0   0   0   0
# 456  457   Sheldon Neuse\neusesh01   26  LAD  NL  1   2   2  0  0   0   0   0
#
#      RBI  SB  CS  BB  SO   BA  OBP  SLG  OPS   OPS+  TB  GDP  HBP  SH  SF  \
# 343    0   0   0   1   1  0.0  0.5  0.0  0.5   56.0   0    0    0   0   0
# 406    0   0   0   1   4  0.0  0.2  0.0  0.2  -36.0   0    0    0   0   0
# 456    0   0   0   0   2  0.0  0.0  0.0  0.0 -100.0   0    0    0   0   0
#
#      IBB Pos Summary  SO/AB
# 343    0          /H    1.0
# 406    0         /HD    1.0
# 456    0          /4    1.0

# %%
plt.scatter(data["AB"], data["SO/AB"])
plt.xlabel("At-Bats (AB)")
plt.ylabel("Strikeouts per At-Bat (SO/AB)")
plt.title("SO/AB vs At-Bats")
plt.show()

# From this graph, we can infer that there is a correlation between a higher number of at bats and a lower SO/AB ratio
